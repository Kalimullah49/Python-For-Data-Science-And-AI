# %%
import pandas as pd
import numpy as np

# %%
#np.nan numerical pythn sa hm na not a numbr banaya ha numerically value ko khali kar dai numpy na
#salty ke example
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
#
dates = pd.date_range("20240101", periods=6)

dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
#
dates = pd.date_range("20240101", periods=15)

dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12',
#                '2024-01-13', '2024-01-14', '2024-01-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
#
dates = pd.date_range("20240101", periods=30)

dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12',
#                '2024-01-13', '2024-01-14', '2024-01-15', '2024-01-16',
#                '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-20',
#                '2024-01-21', '2024-01-22', '2024-01-23', '2024-01-24',
#                '2024-01-25', '2024-01-26', '2024-01-27', '2024-01-28',
#                '2024-01-29', '2024-01-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
#
dates = pd.date_range("20130101", periods=6)

dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Datafarame, numpy ke library sa bana rahay ha,rendomly
# ya 4 colum ke value numpy na random de han
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

df
# Out:
#                    A         B         C         D
# 2013-01-01  0.869194  0.250341  1.096224 -1.338594
# 2013-01-02  0.674040 -0.318494 -2.270032 -0.618018
# 2013-01-03 -1.174326 -2.067813  1.955604 -0.358017
# 2013-01-04 -0.589345  2.462783  0.438372  0.426077
# 2013-01-05  0.272691 -0.672436 -1.357084 -0.078196
# 2013-01-06 -0.277076 -1.278473  1.154174 -1.225749

# %%
# Dictionar
dict = {"kalim":6.0,"Aqsa":5.5}

# %%
#
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)


df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
#dtype sa hm na data ke type dakhe ha e.g flot,int,obj
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.869194  0.250341  1.096224 -1.338594
# 2013-01-02  0.674040 -0.318494 -2.270032 -0.618018
# 2013-01-03 -1.174326 -2.067813  1.955604 -0.358017
# 2013-01-04 -0.589345  2.462783  0.438372  0.426077
# 2013-01-05  0.272691 -0.672436 -1.357084 -0.078196
# 2013-01-06 -0.277076 -1.278473  1.154174 -1.225749

# %%
#dtype ur info same cheez h
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      datetime64[s]
#  2   C       4 non-null      float32
#  3   D       4 non-null      int32
#  4   E       4 non-null      category
#  5   F       4 non-null      object
# dtypes: category(1), datetime64[s](1), float32(1), float64(1), int32(1), object(1)
# memory usage: 288.0+ bytes

# %%
# pandas ma row ur colum ma the numpy na 2D data ma tabdeel kr de
df.to_numpy()
# Out:
# array([[ 0.86919369,  0.2503412 ,  1.09622433, -1.33859444],
#        [ 0.67404034, -0.31849407, -2.27003179, -0.61801765],
#        [-1.17432578, -2.06781258,  1.95560427, -0.35801704],
#        [-0.58934471,  2.46278263,  0.43837228,  0.4260768 ],
#        [ 0.27269113, -0.67243629, -1.35708386, -0.07819562],
#        [-0.27707615, -1.27847319,  1.15417411, -1.22574851]])

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.869194  0.250341  1.096224 -1.338594
# 2013-01-02  0.674040 -0.318494 -2.270032 -0.618018
# 2013-01-03 -1.174326 -2.067813  1.955604 -0.358017
# 2013-01-04 -0.589345  2.462783  0.438372  0.426077
# 2013-01-05  0.272691 -0.672436 -1.357084 -0.078196

# %%
# rail ma () ni lagani
df.tail
# Out:
# <bound method NDFrame.tail of                    A         B         C         D
# 2013-01-01  0.869194  0.250341  1.096224 -1.338594
# 2013-01-02  0.674040 -0.318494 -2.270032 -0.618018
# 2013-01-03 -1.174326 -2.067813  1.955604 -0.358017
# 2013-01-04 -0.589345  2.462783  0.438372  0.426077
# 2013-01-05  0.272691 -0.672436 -1.357084 -0.078196
# 2013-01-06 -0.277076 -1.278473  1.154174 -1.225749>

# %%
#index ma () ni lagani
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.869194  0.250341  1.096224 -1.338594
# 2013-01-02  0.674040 -0.318494 -2.270032 -0.618018
# 2013-01-03 -1.174326 -2.067813  1.955604 -0.358017
# 2013-01-04 -0.589345  2.462783  0.438372  0.426077
# 2013-01-05  0.272691 -0.672436 -1.357084 -0.078196
# 2013-01-06 -0.277076 -1.278473  1.154174 -1.225749

# %%
df.to_numpy()
# Out:
# array([[-1.36969288, -1.77946791,  0.46516913, -1.50803245],
#        [ 0.0293232 ,  0.45925999, -0.24758365,  0.5139172 ],
#        [-0.23848311, -0.11360489, -0.99695008,  1.50189898],
#        [-0.87656903, -0.67156145, -0.06208614,  1.22890397],
#        [ 1.2376788 ,  0.49499219,  0.64471593, -1.51293978],
#        [-0.44711783,  1.63201248, -0.05104241, -0.44309344]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.277477  0.003605 -0.041296 -0.036558
# std    0.891288  1.161872  0.580254  1.325253
# min   -1.369693 -1.779468 -0.996950 -1.512940
# 25%   -0.769206 -0.532072 -0.201209 -1.241798
# 50%   -0.342800  0.172828 -0.056564  0.035412
# 75%   -0.037628  0.486059  0.336116  1.050157
# max    1.237679  1.632012  0.644716  1.501899

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.369693 -1.779468  0.465169 -1.508032
# 2013-01-02  0.029323  0.459260 -0.247584  0.513917
# 2013-01-03 -0.238483 -0.113605 -0.996950  1.501899
# 2013-01-04 -0.876569 -0.671561 -0.062086  1.228904
# 2013-01-05  1.237679  0.494992  0.644716 -1.512940
# 2013-01-06 -0.447118  1.632012 -0.051042 -0.443093

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -1.369693    0.029323   -0.238483   -0.876569    1.237679   -0.447118
# B   -1.779468    0.459260   -0.113605   -0.671561    0.494992    1.632012
# C    0.465169   -0.247584   -0.996950   -0.062086    0.644716   -0.051042
# D   -1.508032    0.513917    1.501899    1.228904   -1.512940   -0.443093

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.369693 -1.779468  0.465169 -1.508032
# 2013-01-02  0.029323  0.459260 -0.247584  0.513917
# 2013-01-03 -0.238483 -0.113605 -0.996950  1.501899
# 2013-01-04 -0.876569 -0.671561 -0.062086  1.228904
# 2013-01-05  1.237679  0.494992  0.644716 -1.512940
# 2013-01-06 -0.447118  1.632012 -0.051042 -0.443093

# %%
# axis 1 ho ga to row change hun ge
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.508032  0.465169 -1.779468 -1.369693
# 2013-01-02  0.513917 -0.247584  0.459260  0.029323
# 2013-01-03  1.501899 -0.996950 -0.113605 -0.238483
# 2013-01-04  1.228904 -0.062086 -0.671561 -0.876569
# 2013-01-05 -1.512940  0.644716  0.494992  1.237679
# 2013-01-06 -0.443093 -0.051042  1.632012 -0.447118

# %%
# axis 0 hun ga to colum change ho ga
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-06 -0.447118  1.632012 -0.051042 -0.443093
# 2013-01-05  1.237679  0.494992  0.644716 -1.512940
# 2013-01-04 -0.876569 -0.671561 -0.062086  1.228904
# 2013-01-03 -0.238483 -0.113605 -0.996950  1.501899
# 2013-01-02  0.029323  0.459260 -0.247584  0.513917
# 2013-01-01 -1.369693 -1.779468  0.465169 -1.508032

# %%
# Assol: Row ka axis kya hota ha ur colum ka axis kia hota ha ur isy yad kasy rakhana ha
# menar pakistan ke example : jab axix 1 ho ga to colum ho ga
# jab axix o ho ga to banda koi kam ni karta banda lata hua hota ha mean ka row
# assending=fales mean :Decending

# %% [markdown]
# ### df.sort_values(by="B")

# %%
# b ke value ko sort kia ha is function sa 
#  colum B ke jo valu zayada the vo pahaly aya ge the.
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-01 -1.369693 -1.779468  0.465169 -1.508032
# 2013-01-04 -0.876569 -0.671561 -0.062086  1.228904
# 2013-01-03 -0.238483 -0.113605 -0.996950  1.501899
# 2013-01-02  0.029323  0.459260 -0.247584  0.513917
# 2013-01-05  1.237679  0.494992  0.644716 -1.512940
# 2013-01-06 -0.447118  1.632012 -0.051042 -0.443093

# %%
# Agar hm na 2 colum ko sort karna ho to
# is ma phaly clum A ko SORT karry ga
df.sort_values(by=["A","B"])
# Out:
#                    A         B         C         D
# 2013-01-01 -1.369693 -1.779468  0.465169 -1.508032
# 2013-01-04 -0.876569 -0.671561 -0.062086  1.228904
# 2013-01-06 -0.447118  1.632012 -0.051042 -0.443093
# 2013-01-03 -0.238483 -0.113605 -0.996950  1.501899
# 2013-01-02  0.029323  0.459260 -0.247584  0.513917
# 2013-01-05  1.237679  0.494992  0.644716 -1.512940

# %%
# is ma phaly clum B ko SORT karry ga
df.sort_values(by=["B","A"])
# Out:
#                    A         B         C         D
# 2013-01-01 -1.369693 -1.779468  0.465169 -1.508032
# 2013-01-04 -0.876569 -0.671561 -0.062086  1.228904
# 2013-01-03 -0.238483 -0.113605 -0.996950  1.501899
# 2013-01-02  0.029323  0.459260 -0.247584  0.513917
# 2013-01-05  1.237679  0.494992  0.644716 -1.512940
# 2013-01-06 -0.447118  1.632012 -0.051042 -0.443093

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.369693 -1.779468  0.465169 -1.508032
# 2013-01-02  0.029323  0.459260 -0.247584  0.513917
# 2013-01-03 -0.238483 -0.113605 -0.996950  1.501899
# 2013-01-04 -0.876569 -0.671561 -0.062086  1.228904
# 2013-01-05  1.237679  0.494992  0.644716 -1.512940
# 2013-01-06 -0.447118  1.632012 -0.051042 -0.443093

# %% [markdown]
# ### Getitem ([])

# %%
# AFR  HM NA SARIF AK CLUM PRINT KRWANA HA
df["A"]
# Out:
# 2013-01-01   -1.369693
# 2013-01-02    0.029323
# 2013-01-03   -0.238483
# 2013-01-04   -0.876569
# 2013-01-05    1.237679
# 2013-01-06   -0.447118
# Freq: D, Name: A, dtype: float64

# %%
# agr 2 colum print krwana ho to
df[["A","B"]]
# Out:
#                    A         B
# 2013-01-01 -1.369693 -1.779468
# 2013-01-02  0.029323  0.459260
# 2013-01-03 -0.238483 -0.113605
# 2013-01-04 -0.876569 -0.671561
# 2013-01-05  1.237679  0.494992
# 2013-01-06 -0.447118  1.632012

# %%
df.shape
# Out:
# (6, 4)

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -1.369693 -1.779468  0.465169 -1.508032
# 2013-01-02  0.029323  0.459260 -0.247584  0.513917
# 2013-01-03 -0.238483 -0.113605 -0.996950  1.501899

# %%
# 0 to 3 rows ke range ha ur 0 to 2 colum ke rang ha
df.iloc[0:5,0:2]
# Out:
#                    A         B
# 2013-01-01 -1.369693 -1.779468
# 2013-01-02  0.029323  0.459260
# 2013-01-03 -0.238483 -0.113605
# 2013-01-04 -0.876569 -0.671561
# 2013-01-05  1.237679  0.494992

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2013-01-01 -1.369693 -1.779468
# 2013-01-02  0.029323  0.459260
# 2013-01-03 -0.238483 -0.113605
# 2013-01-04 -0.876569 -0.671561
# 2013-01-05  1.237679  0.494992
# 2013-01-06 -0.447118  1.632012

# %%
# Assigment
# what is difference btween lock and i lock function

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.369693 -1.779468  0.465169 -1.508032
# 2013-01-02  0.029323  0.459260 -0.247584  0.513917
# 2013-01-03 -0.238483 -0.113605 -0.996950  1.501899
# 2013-01-04 -0.876569 -0.671561 -0.062086  1.228904
# 2013-01-05  1.237679  0.494992  0.644716 -1.512940
# 2013-01-06 -0.447118  1.632012 -0.051042 -0.443093

# %%
df.iloc[3]
# Out:
# A   -0.876569
# B   -0.671561
# C   -0.062086
# D    1.228904
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
 # ilock,lock,index used for sclicing

# %%
import seaborn as sns

# %%
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# cezoon ka tukary tukary kar ka marzi ka tuky uthana : known as sampling.
# is function sa hm na kashti sa random 100 value lany ha
kashti.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 108         0       3    male  38.0      0      0   7.8958        S   Third
# 446         1       2  female  13.0      0      1  19.5000        S  Second
# 245         0       1    male  44.0      2      0  90.0000        Q   First
# 173         0       3    male  21.0      0      0   7.9250        S   Third
# 564         0       3  female   NaN      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 656         0       3    male   NaN      0      0   7.8958        S   Third
# 91          0       3    male  20.0      0      0   7.8542        S   Third
# 449         1       1    male  52.0      0      0  30.5000        S   First
# 628         0       3    male  26.0      0      0   7.8958        S   Third
# 265         0       2    male  36.0      0      0  10.5000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# #### Boolean indexing

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  0.029323  0.459260 -0.247584  0.513917
# 2013-01-05  1.237679  0.494992  0.644716 -1.512940

# %%
# filtering data using condational operator
kashti[kashti["age"]< 5]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male  2.00      3      1   21.0750        S   Third
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 16          0       3    male  2.00      4      1   29.1250        Q   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 63          0       3    male  4.00      3      2   27.9000        S   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 171         0       3    male  4.00      4      1   29.1250        Q   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# ...

# %%
# 1 sal sa kam waly kary ka baghoir ni gy
kashti[kashti["age"]< 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 831         1       2    male  0.83      1      1   18.7500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 78   child       False  NaN  Southampton   yes  False
# 305  child       False    C  Southampton   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# ...

# %%
kashti[kashti["age"]< 60]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti[kashti["fare"]< 5]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked   class  who  \
# 179         0       3  male  36.0      0      0  0.0000        S   Third  man
# 263         0       1  male  40.0      0      0  0.0000        S   First  man
# 271         1       3  male  25.0      0      0  0.0000        S   Third  man
# 277         0       2  male   NaN      0      0  0.0000        S  Second  man
# 302         0       3  male  19.0      0      0  0.0000        S   Third  man
# 378         0       3  male  20.0      0      0  4.0125        C   Third  man
# 413         0       2  male   NaN      0      0  0.0000        S  Second  man
# 466         0       2  male   NaN      0      0  0.0000        S  Second  man
# 481         0       2  male   NaN      0      0  0.0000        S  Second  man
# 597         0       3  male  49.0      0      0  0.0000        S   Third  man
# 633         0       1  male   NaN      0      0  0.0000        S   First  man
# ...
